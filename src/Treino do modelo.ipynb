# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# plots accuracy and loss curves


def plot_model_history(model_history):
    """
    Plot Accuracy and Loss curves given the model_history
    """
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    # summarize history for accuracy
    axs[0].plot(range(1, len(model_history.history['accuracy'])+1),
                model_history.history['accuracy'])
    axs[0].plot(range(1, len(model_history.history['val_accuracy'])+1),
                model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1, len(model_history.history['accuracy'])+1),
                      len(model_history.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1, len(model_history.history['loss'])+1),
                model_history.history['loss'])
    axs[1].plot(range(1, len(model_history.history['val_loss'])+1),
                model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(
        1, len(model_history.history['loss'])+1), len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    fig.savefig('plot.png')
    plt.show()


# Define data generators
train_dir = '/content/drive/MyDrive/Colab Datasets/data/train'
val_dir = '/content/drive/MyDrive/Colab Datasets/data/test'

num_train = 28709
num_val = 7178
batch_size = 64
num_epoch = 50

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(48, 48),
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical')

# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3),
          activation='relu', input_shape=(48, 48, 1)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer=Adam(
 learning_rate=0.0001, epsilon=1e-6), metrics=['accuracy'])
model_info = model.fit_generator(
  train_generator,
  steps_per_epoch=num_train // batch_size,
  epochs=num_epoch,
  validation_data=validation_generator,
  validation_steps=num_val // batch_size)

model.save_weights('model.h5')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# <ipython-input-5-01804cb8dce8>:94: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_info = model.fit_generator(
# Epoch 1/50
# 448/448 [==============================] - 2463s 5s/step - loss: 1.8002 - accuracy: 0.2612 - val_loss: 1.7038 - val_accuracy: 0.3417
# Epoch 2/50
# 448/448 [==============================] - 56s 125ms/step - loss: 1.6231 - accuracy: 0.3686 - val_loss: 1.5345 - val_accuracy: 0.4182
# Epoch 3/50
# 448/448 [==============================] - 55s 123ms/step - loss: 1.5196 - accuracy: 0.4177 - val_loss: 1.4536 - val_accuracy: 0.4434
# Epoch 4/50
# 448/448 [==============================] - 56s 125ms/step - loss: 1.4447 - accuracy: 0.4475 - val_loss: 1.3911 - val_accuracy: 0.4664
# Epoch 5/50
# 448/448 [==============================] - 55s 123ms/step - loss: 1.3868 - accuracy: 0.4720 - val_loss: 1.3329 - val_accuracy: 0.4958
# Epoch 6/50
# 448/448 [==============================] - 56s 125ms/step - loss: 1.3363 - accuracy: 0.4913 - val_loss: 1.2959 - val_accuracy: 0.5100
# Epoch 7/50
# 448/448 [==============================] - 55s 123ms/step - loss: 1.2924 - accuracy: 0.5092 - val_loss: 1.2733 - val_accuracy: 0.5176
# Epoch 8/50
# 448/448 [==============================] - 55s 123ms/step - loss: 1.2537 - accuracy: 0.5277 - val_loss: 1.2426 - val_accuracy: 0.5241
# Epoch 9/50
# 448/448 [==============================] - 55s 122ms/step - loss: 1.2236 - accuracy: 0.5396 - val_loss: 1.2100 - val_accuracy: 0.5413
# Epoch 10/50
# 448/448 [==============================] - 55s 124ms/step - loss: 1.1911 - accuracy: 0.5534 - val_loss: 1.1989 - val_accuracy: 0.5452
# Epoch 11/50
# 448/448 [==============================] - 55s 122ms/step - loss: 1.1613 - accuracy: 0.5618 - val_loss: 1.1697 - val_accuracy: 0.5605
# Epoch 12/50
# 448/448 [==============================] - 55s 122ms/step - loss: 1.1344 - accuracy: 0.5772 - val_loss: 1.1580 - val_accuracy: 0.5702
# Epoch 13/50
# 448/448 [==============================] - 54s 121ms/step - loss: 1.1147 - accuracy: 0.5817 - val_loss: 1.1431 - val_accuracy: 0.5705
# Epoch 14/50
# 448/448 [==============================] - 54s 121ms/step - loss: 1.0848 - accuracy: 0.5969 - val_loss: 1.1373 - val_accuracy: 0.5769
# Epoch 15/50
# 448/448 [==============================] - 55s 123ms/step - loss: 1.0602 - accuracy: 0.6045 - val_loss: 1.1269 - val_accuracy: 0.5767
# Epoch 16/50
# 448/448 [==============================] - 54s 121ms/step - loss: 1.0372 - accuracy: 0.6144 - val_loss: 1.1170 - val_accuracy: 0.5802
# Epoch 17/50
# 448/448 [==============================] - 55s 122ms/step - loss: 1.0112 - accuracy: 0.6256 - val_loss: 1.1001 - val_accuracy: 0.5887
# Epoch 18/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.9888 - accuracy: 0.6304 - val_loss: 1.0975 - val_accuracy: 0.5910
# Epoch 19/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.9611 - accuracy: 0.6449 - val_loss: 1.0862 - val_accuracy: 0.5967
# Epoch 20/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.9349 - accuracy: 0.6548 - val_loss: 1.1131 - val_accuracy: 0.5876
# Epoch 21/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.9137 - accuracy: 0.6654 - val_loss: 1.0791 - val_accuracy: 0.6042
# Epoch 22/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.8905 - accuracy: 0.6716 - val_loss: 1.0829 - val_accuracy: 0.5989
# Epoch 23/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.8688 - accuracy: 0.6773 - val_loss: 1.0787 - val_accuracy: 0.6031
# Epoch 24/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.8373 - accuracy: 0.6957 - val_loss: 1.0676 - val_accuracy: 0.6081
# Epoch 25/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.8188 - accuracy: 0.7017 - val_loss: 1.0744 - val_accuracy: 0.6051
# Epoch 26/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.7943 - accuracy: 0.7099 - val_loss: 1.0725 - val_accuracy: 0.6104
# Epoch 27/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.7696 - accuracy: 0.7191 - val_loss: 1.0880 - val_accuracy: 0.6062
# Epoch 28/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.7426 - accuracy: 0.7288 - val_loss: 1.0750 - val_accuracy: 0.6168
# Epoch 29/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.7136 - accuracy: 0.7430 - val_loss: 1.0929 - val_accuracy: 0.6104
# Epoch 30/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.7030 - accuracy: 0.7421 - val_loss: 1.0903 - val_accuracy: 0.6147
# Epoch 31/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.6753 - accuracy: 0.7553 - val_loss: 1.0857 - val_accuracy: 0.6127
# Epoch 32/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.6513 - accuracy: 0.7612 - val_loss: 1.0936 - val_accuracy: 0.6237
# Epoch 33/50
# 448/448 [==============================] - 55s 123ms/step - loss: 0.6346 - accuracy: 0.7699 - val_loss: 1.0948 - val_accuracy: 0.6193
# Epoch 34/50
# 448/448 [==============================] - 56s 124ms/step - loss: 0.6091 - accuracy: 0.7789 - val_loss: 1.0987 - val_accuracy: 0.6186
# Epoch 35/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.5963 - accuracy: 0.7827 - val_loss: 1.1032 - val_accuracy: 0.6187
# Epoch 36/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.5745 - accuracy: 0.7930 - val_loss: 1.1033 - val_accuracy: 0.6203
# Epoch 37/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.5518 - accuracy: 0.8013 - val_loss: 1.1120 - val_accuracy: 0.6219
# Epoch 38/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.5351 - accuracy: 0.8059 - val_loss: 1.1022 - val_accuracy: 0.6193
# Epoch 39/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.5112 - accuracy: 0.8160 - val_loss: 1.1189 - val_accuracy: 0.6219
# Epoch 40/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.4972 - accuracy: 0.8191 - val_loss: 1.1430 - val_accuracy: 0.6203
# Epoch 41/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.4810 - accuracy: 0.8272 - val_loss: 1.1436 - val_accuracy: 0.6212
# Epoch 42/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.4674 - accuracy: 0.8293 - val_loss: 1.1483 - val_accuracy: 0.6249
# Epoch 43/50
# 448/448 [==============================] - 55s 122ms/step - loss: 0.4446 - accuracy: 0.8410 - val_loss: 1.1648 - val_accuracy: 0.6225
# Epoch 44/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.4378 - accuracy: 0.8423 - val_loss: 1.1689 - val_accuracy: 0.6228
# Epoch 45/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.4253 - accuracy: 0.8475 - val_loss: 1.1632 - val_accuracy: 0.6236
# Epoch 46/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.4112 - accuracy: 0.8522 - val_loss: 1.1824 - val_accuracy: 0.6228
# Epoch 47/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.3983 - accuracy: 0.8555 - val_loss: 1.1843 - val_accuracy: 0.6212
# Epoch 48/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.3801 - accuracy: 0.8622 - val_loss: 1.2243 - val_accuracy: 0.6193
# Epoch 49/50
# 448/448 [==============================] - 54s 121ms/step - loss: 0.3653 - accuracy: 0.8686 - val_loss: 1.2207 - val_accuracy: 0.6247
# Epoch 50/50
# 448/448 [==============================] - 54s 120ms/step - loss: 0.3694 - accuracy: 0.8680 - val_loss: 1.2054 - val_accuracy: 0.6323
